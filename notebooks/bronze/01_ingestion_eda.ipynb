# %% [markdown]
# # Bronze Layer — Ingestion & EDA
#
# Explore and profile the raw source data before it enters the pipeline.
# Use this notebook to understand data quality, distributions, and edge cases.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))

from pipeline.entities.config import DATA_DIR, SOURCE_FILE, BRONZE_DIR
from pipeline.controllers.io_adapter import read_csv
from pipeline.layer_transforms.bronze_transforms import apply_bronze_transforms

# %%
import pandas as pd

raw_df = read_csv(DATA_DIR / SOURCE_FILE)
raw_df.head()

# %%
raw_df.info()

# %%
raw_df.describe()
