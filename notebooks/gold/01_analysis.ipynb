# %% [markdown]
# # Gold Layer — Analysis & Visualization
#
# Consume gold-layer datasets for insights, charts, and reporting.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))

from pipeline.entities.config import GOLD_DIR

# %%
import pandas as pd

correlation = pd.read_csv(GOLD_DIR / "gold_correlation_matrix.csv")
lifestyle = pd.read_csv(GOLD_DIR / "gold_lifestyle_impact.csv")
risk = pd.read_csv(GOLD_DIR / "gold_risk_profiles.csv")

print(f"Correlation: {correlation.shape}")
print(f"Lifestyle:   {lifestyle.shape}")
print(f"Risk:        {risk.shape}")

# %%
correlation.head()
