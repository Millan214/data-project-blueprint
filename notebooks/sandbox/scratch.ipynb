# %% [markdown]
# # Sandbox — Scratch Notebook
#
# Free-form experiments. No specific layer — just a quick setup cell.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
from pipeline.entities import config
